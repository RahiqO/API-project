# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\16475\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\16475\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats
import scipy as lingregress 
import seaborn as sb 
# Impor the OpenWeatherMap API key
from api_keys import ap_k

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 627

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
api_key = "30b0a0c0639bef228216402f04668c40"

# %%
# Set the API base URL
url =" https://api.openweathermap.org/data/2.5/weather?"  

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
   
    city_url = f"{url}q={city}&appid={api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

#     # Run an API request for each of the cities
    try:
 
            # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({
              "City": city, 
              "Lat": city_lat, 
              "Lng": city_lng, 
              "Max Temp": city_max_temp,
              "Humidity": city_humidity,
              "Cloudiness": city_clouds,
              "Wind Speed": city_wind,
              "Country": city_country,
              "Date": city_date})


#     # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | xichang
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | batagay
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | roma
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | mayo
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | jacareacanga
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | sola
# Processing Record 16 of Set 1 | merke
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | garissa
# Processing Record 19 of Set 1 | harper
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 24 of Set 1 | taksimo
# Processing Record 25 of Set 1 | bonthe
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | cabo san lucas
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | huanren
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | phalaborwa
# Processing Record 33 of Set 1 | gazanjyk
# Processing Record 34 of Set 1 | kristiansund
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | gryazovets
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | sao joao da barra
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | syracuse
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | bjornevatn
# Processing Record 0 of Set 2 | tlyarota
# City not found. Skipping...
# Processing Record 1 of Set 2 | olafsvik
# Processing Record 2 of Set 2 | mananjary
# Processing Record 3 of Set 2 | grong
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | pacific grove
# Processing Record 9 of Set 2 | illintsi
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | davenda
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | bowen
# Processing Record 15 of Set 2 | bambanglipuro
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 2 | souris
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | badiraguato
# Processing Record 29 of Set 2 | almaznyy
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | ulladulla
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | urbano santos
# Processing Record 34 of Set 2 | san quintin
# Processing Record 35 of Set 2 | oranjemund
# Processing Record 36 of Set 2 | turukhansk
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | seoul
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | kondinskoye
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | bathsheba
# Processing Record 46 of Set 2 | mountain home
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | iisalmi
# Processing Record 0 of Set 3 | porto
# Processing Record 1 of Set 3 | tezu
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | vangaindrano
# Processing Record 4 of Set 3 | bocana de paiwas
# Processing Record 5 of Set 3 | washougal
# Processing Record 6 of Set 3 | oriximina
# Processing Record 7 of Set 3 | limon
# Processing Record 8 of Set 3 | rancho veloz
# Processing Record 9 of Set 3 | xaxim
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | homer
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | esfarayen
# Processing Record 16 of Set 3 | chingirlau
# Processing Record 17 of Set 3 | tanhacu
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | jumla
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | burnie
# Processing Record 24 of Set 3 | meulaboh
# Processing Record 25 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 26 of Set 3 | bell ville
# Processing Record 27 of Set 3 | port hardy
# Processing Record 28 of Set 3 | sur
# Processing Record 29 of Set 3 | kushmurun
# Processing Record 30 of Set 3 | hermanus
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | tongliao
# Processing Record 33 of Set 3 | najran
# Processing Record 34 of Set 3 | sao miguel do araguaia
# Processing Record 35 of Set 3 | kachug
# Processing Record 36 of Set 3 | waipawa
# Processing Record 37 of Set 3 | cockburn town
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 3 | dindori
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | bollnas
# Processing Record 43 of Set 3 | nantucket
# Processing Record 44 of Set 3 | ketchikan
# Processing Record 45 of Set 3 | yugorsk
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | porto novo
# Processing Record 48 of Set 3 | isla vista
# Processing Record 49 of Set 3 | yenagoa
# Processing Record 0 of Set 4 | castro
# Processing Record 1 of Set 4 | asmara
# Processing Record 2 of Set 4 | kulhudhuffushi
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | teya
# Processing Record 5 of Set 4 | orlik
# Processing Record 6 of Set 4 | saldanha
# Processing Record 7 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | munkebo
# Processing Record 11 of Set 4 | dorokhovo
# Processing Record 12 of Set 4 | flin flon
# Processing Record 13 of Set 4 | nikolskoye
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | mirante do paranapanema
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | sept-iles
# Processing Record 18 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 4 | bluff
# Processing Record 20 of Set 4 | atasu
# Processing Record 21 of Set 4 | gagret
# Processing Record 22 of Set 4 | vaini
# Processing Record 23 of Set 4 | pemberton
# Processing Record 24 of Set 4 | buala
# Processing Record 25 of Set 4 | tautira
# Processing Record 26 of Set 4 | xalpatlahuac
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | hambantota
# Processing Record 29 of Set 4 | rawson
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | touho
# Processing Record 33 of Set 4 | hervey bay
# Processing Record 34 of Set 4 | hovd
# Processing Record 35 of Set 4 | izhma
# Processing Record 36 of Set 4 | straseni
# Processing Record 37 of Set 4 | da lat
# Processing Record 38 of Set 4 | vardo
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | marawi
# Processing Record 41 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | puerto madero
# Processing Record 44 of Set 4 | krasnoarmeysk
# Processing Record 45 of Set 4 | moranbah
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | sambava
# Processing Record 49 of Set 4 | nome
# Processing Record 0 of Set 5 | sussex
# Processing Record 1 of Set 5 | ambilobe
# Processing Record 2 of Set 5 | halifax
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | evensk
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | les cayes
# Processing Record 7 of Set 5 | whitehorse
# Processing Record 8 of Set 5 | tenenkou
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | cape canaveral
# Processing Record 11 of Set 5 | samarai
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | del rio
# Processing Record 14 of Set 5 | loa janan
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | maniitsoq
# Processing Record 17 of Set 5 | planeta rica
# Processing Record 18 of Set 5 | joshimath
# Processing Record 19 of Set 5 | umm lajj
# Processing Record 20 of Set 5 | abbeville
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | san lorenzo
# Processing Record 23 of Set 5 | wad rawah
# Processing Record 24 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 5 | zhangdian
# Processing Record 26 of Set 5 | belaya gora
# Processing Record 27 of Set 5 | nanortalik
# Processing Record 28 of Set 5 | naliya
# Processing Record 29 of Set 5 | hangu
# Processing Record 30 of Set 5 | khani
# Processing Record 31 of Set 5 | inongo
# Processing Record 32 of Set 5 | tucuman
# Processing Record 33 of Set 5 | lalomanu
# City not found. Skipping...
# Processing Record 34 of Set 5 | mulki
# Processing Record 35 of Set 5 | camana
# Processing Record 36 of Set 5 | miri
# Processing Record 37 of Set 5 | santa cruz de tenerife
# Processing Record 38 of Set 5 | mayna
# Processing Record 39 of Set 5 | aquidauana
# Processing Record 40 of Set 5 | aguimes
# Processing Record 41 of Set 5 | nyurba
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | alyangula
# Processing Record 45 of Set 5 | samalkha
# Processing Record 46 of Set 5 | iznik
# Processing Record 47 of Set 5 | mount isa
# Processing Record 48 of Set 5 | westport
# Processing Record 49 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 0 of Set 6 | kirakira
# Processing Record 1 of Set 6 | sechura
# Processing Record 2 of Set 6 | mareeba
# Processing Record 3 of Set 6 | pullman
# Processing Record 4 of Set 6 | sao borja
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | arman
# Processing Record 7 of Set 6 | russell
# Processing Record 8 of Set 6 | itoman
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | rabo de peixe
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | palora
# Processing Record 13 of Set 6 | sampit
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | vilhena
# Processing Record 16 of Set 6 | pozo colorado
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 19 of Set 6 | ahuimanu
# Processing Record 20 of Set 6 | gao
# Processing Record 21 of Set 6 | belyy yar
# Processing Record 22 of Set 6 | estevan
# Processing Record 23 of Set 6 | sorland
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | bang saphan
# Processing Record 28 of Set 6 | madison
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | saint-pierre
# Processing Record 31 of Set 6 | namatanai
# Processing Record 32 of Set 6 | saint-francois
# Processing Record 33 of Set 6 | kralendijk
# Processing Record 34 of Set 6 | achacachi
# Processing Record 35 of Set 6 | ojinaga
# Processing Record 36 of Set 6 | alice springs
# Processing Record 37 of Set 6 | dahuk
# Processing Record 38 of Set 6 | qaqortoq
# Processing Record 39 of Set 6 | lavrentiya
# Processing Record 40 of Set 6 | the valley
# Processing Record 41 of Set 6 | hami
# Processing Record 42 of Set 6 | san joaquin
# Processing Record 43 of Set 6 | bonavista
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | tonj
# Processing Record 46 of Set 6 | galle
# Processing Record 47 of Set 6 | danshui
# Processing Record 48 of Set 6 | ziro
# Processing Record 49 of Set 6 | hofn
# Processing Record 0 of Set 7 | taoudenni
# Processing Record 1 of Set 7 | alta floresta
# Processing Record 2 of Set 7 | denpasar
# Processing Record 3 of Set 7 | nova olimpia
# Processing Record 4 of Set 7 | fort-shevchenko
# Processing Record 5 of Set 7 | ulaanbaatar
# Processing Record 6 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 7 | sao paulo de olivenca
# Processing Record 8 of Set 7 | batemans bay
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | torbay
# Processing Record 11 of Set 7 | guerrero negro
# Processing Record 12 of Set 7 | sedro-woolley
# Processing Record 13 of Set 7 | zhanakorgan
# Processing Record 14 of Set 7 | tarko-sale
# Processing Record 15 of Set 7 | darnah
# Processing Record 16 of Set 7 | kastrakion
# Processing Record 17 of Set 7 | paveh
# Processing Record 18 of Set 7 | dargaville
# Processing Record 19 of Set 7 | ogaminana
# Processing Record 20 of Set 7 | acapulco
# Processing Record 21 of Set 7 | timbiqui
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | bizhbulyak
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | port-gentil
# Processing Record 26 of Set 7 | kasongo
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | senanga
# Processing Record 29 of Set 7 | dali
# Processing Record 30 of Set 7 | kutum
# Processing Record 31 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 7 | sterling
# Processing Record 33 of Set 7 | mackay
# Processing Record 34 of Set 7 | mopipi
# Processing Record 35 of Set 7 | la paz
# Processing Record 36 of Set 7 | colquechaca
# Processing Record 37 of Set 7 | leeuwarden
# Processing Record 38 of Set 7 | itarema
# Processing Record 39 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 7 | gambela
# Processing Record 41 of Set 7 | maragogi
# Processing Record 42 of Set 7 | nizhnyaya poyma
# Processing Record 43 of Set 7 | elmira
# Processing Record 44 of Set 7 | sayyan
# Processing Record 45 of Set 7 | abu samrah
# City not found. Skipping...
# Processing Record 46 of Set 7 | khromtau
# City not found. Skipping...
# Processing Record 47 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 7 | bundaberg
# Processing Record 49 of Set 7 | gritsovskiy
# Processing Record 0 of Set 8 | spring valley
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | belmonte
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | vung tau
# Processing Record 5 of Set 8 | puerto del rosario
# Processing Record 6 of Set 8 | great yarmouth
# Processing Record 7 of Set 8 | cayenne
# Processing Record 8 of Set 8 | raudeberg
# Processing Record 9 of Set 8 | lewiston
# Processing Record 10 of Set 8 | fairlie
# Processing Record 11 of Set 8 | port hedland
# Processing Record 12 of Set 8 | victoria
# Processing Record 13 of Set 8 | nanhai
# Processing Record 14 of Set 8 | atkinson
# Processing Record 15 of Set 8 | stratonion
# Processing Record 16 of Set 8 | svetlaya
# Processing Record 17 of Set 8 | berdigestyakh
# Processing Record 18 of Set 8 | conde
# Processing Record 19 of Set 8 | sao filipe
# Processing Record 20 of Set 8 | katsuura
# Processing Record 21 of Set 8 | yulara
# Processing Record 22 of Set 8 | nadym
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | el vendrell
# Processing Record 25 of Set 8 | kyra
# Processing Record 26 of Set 8 | kununurra
# Processing Record 27 of Set 8 | wajid
# Processing Record 28 of Set 8 | amuntai
# Processing Record 29 of Set 8 | west lafayette
# Processing Record 30 of Set 8 | adrar
# Processing Record 31 of Set 8 | myanaung
# Processing Record 32 of Set 8 | novoagansk
# Processing Record 33 of Set 8 | soyo
# Processing Record 34 of Set 8 | airai
# Processing Record 35 of Set 8 | cascais
# Processing Record 36 of Set 8 | chuy
# Processing Record 37 of Set 8 | verkh-usugli
# Processing Record 38 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 8 | kot radha kishan
# Processing Record 41 of Set 8 | tigil
# Processing Record 42 of Set 8 | cherskiy
# Processing Record 43 of Set 8 | udachnyy
# Processing Record 44 of Set 8 | tura
# Processing Record 45 of Set 8 | parauna
# Processing Record 46 of Set 8 | lorengau
# Processing Record 47 of Set 8 | maldonado
# Processing Record 48 of Set 8 | mukhen
# Processing Record 49 of Set 8 | cidreira
# Processing Record 0 of Set 9 | saiki
# Processing Record 1 of Set 9 | xining
# Processing Record 2 of Set 9 | singaraja
# Processing Record 3 of Set 9 | korla
# Processing Record 4 of Set 9 | san andres
# Processing Record 5 of Set 9 | ayan
# Processing Record 6 of Set 9 | morant bay
# Processing Record 7 of Set 9 | tahta
# Processing Record 8 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 9 | baraki barak
# Processing Record 10 of Set 9 | wamba
# Processing Record 11 of Set 9 | banjar
# Processing Record 12 of Set 9 | coronel vivida
# Processing Record 13 of Set 9 | alcantara
# Processing Record 14 of Set 9 | ayame
# Processing Record 15 of Set 9 | kibakwe
# Processing Record 16 of Set 9 | lac du bonnet
# Processing Record 17 of Set 9 | portmore
# Processing Record 18 of Set 9 | tingi
# Processing Record 19 of Set 9 | beloha
# Processing Record 20 of Set 9 | zhezkazgan
# Processing Record 21 of Set 9 | sapapalii
# City not found. Skipping...
# Processing Record 22 of Set 9 | goderich
# Processing Record 23 of Set 9 | yaan
# Processing Record 24 of Set 9 | chagoda
# Processing Record 25 of Set 9 | punta cardon
# Processing Record 26 of Set 9 | elban
# Processing Record 27 of Set 9 | muros
# Processing Record 28 of Set 9 | stornoway
# Processing Record 29 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 9 | georgetown
# Processing Record 31 of Set 9 | mirabad
# Processing Record 32 of Set 9 | yabrud
# Processing Record 33 of Set 9 | bethel
# Processing Record 34 of Set 9 | pasni
# Processing Record 35 of Set 9 | tomatlan
# Processing Record 36 of Set 9 | nouadhibou
# Processing Record 37 of Set 9 | mezen
# Processing Record 38 of Set 9 | parys
# Processing Record 39 of Set 9 | alexandria
# Processing Record 40 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 9 | aykhal
# Processing Record 42 of Set 9 | bismarck
# Processing Record 43 of Set 9 | altay
# Processing Record 44 of Set 9 | san angelo
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | ibotirama
# Processing Record 48 of Set 9 | launceston
# Processing Record 49 of Set 9 | serravalle pistoiese
# Processing Record 0 of Set 10 | luderitz
# Processing Record 1 of Set 10 | srednekolymsk
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | portree
# Processing Record 4 of Set 10 | oum hadjer
# Processing Record 5 of Set 10 | bandarbeyla
# Processing Record 6 of Set 10 | grindavik
# Processing Record 7 of Set 10 | arinos
# Processing Record 8 of Set 10 | pamekasan
# Processing Record 9 of Set 10 | maceio
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | san clemente
# Processing Record 12 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 10 | ballina
# Processing Record 14 of Set 10 | manta
# Processing Record 15 of Set 10 | kangaatsiaq
# Processing Record 16 of Set 10 | port augusta
# Processing Record 17 of Set 10 | tiznit
# Processing Record 18 of Set 10 | necochea
# Processing Record 19 of Set 10 | husavik
# Processing Record 20 of Set 10 | gat
# Processing Record 21 of Set 10 | kalabo
# Processing Record 22 of Set 10 | la rioja
# Processing Record 23 of Set 10 | mnogovershinnyy
# Processing Record 24 of Set 10 | yumen
# Processing Record 25 of Set 10 | diego de almagro
# Processing Record 26 of Set 10 | tiarei
# Processing Record 27 of Set 10 | aksu
# Processing Record 28 of Set 10 | west bridgeford
# City not found. Skipping...
# Processing Record 29 of Set 10 | byron bay
# Processing Record 30 of Set 10 | lazaro cardenas
# Processing Record 31 of Set 10 | promyshlennaya
# Processing Record 32 of Set 10 | orocue
# Processing Record 33 of Set 10 | tara
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | tezze sul brenta
# Processing Record 36 of Set 10 | saint-louis
# Processing Record 37 of Set 10 | coihaique
# Processing Record 38 of Set 10 | inhambane
# Processing Record 39 of Set 10 | regina
# Processing Record 40 of Set 10 | mayumba
# Processing Record 41 of Set 10 | katangli
# Processing Record 42 of Set 10 | taicheng
# Processing Record 43 of Set 10 | kiunga
# Processing Record 44 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 10 | changli
# Processing Record 47 of Set 10 | alekseyevsk
# Processing Record 48 of Set 10 | luchenza
# Processing Record 49 of Set 10 | kavaratti
# Processing Record 0 of Set 11 | zeya
# Processing Record 1 of Set 11 | inirida
# Processing Record 2 of Set 11 | chadiza
# Processing Record 3 of Set 11 | da nang
# Processing Record 4 of Set 11 | san cristobal
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | toyooka
# Processing Record 7 of Set 11 | sobradinho
# Processing Record 8 of Set 11 | fukue
# Processing Record 9 of Set 11 | rocha
# Processing Record 10 of Set 11 | muzaffarpur
# Processing Record 11 of Set 11 | langham
# Processing Record 12 of Set 11 | felanitx
# Processing Record 13 of Set 11 | mangai
# Processing Record 14 of Set 11 | ewa beach
# Processing Record 15 of Set 11 | roros
# Processing Record 16 of Set 11 | makinsk
# Processing Record 17 of Set 11 | bubaque
# Processing Record 18 of Set 11 | opuwo
# Processing Record 19 of Set 11 | ixtapa
# Processing Record 20 of Set 11 | walvis bay
# Processing Record 21 of Set 11 | baykit
# Processing Record 22 of Set 11 | birjand
# Processing Record 23 of Set 11 | kailua
# Processing Record 24 of Set 11 | antalaha
# Processing Record 25 of Set 11 | tayu
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | gizo
# Processing Record 28 of Set 11 | turochak
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | zhanaozen
# Processing Record 31 of Set 11 | koslan
# Processing Record 32 of Set 11 | bako
# Processing Record 33 of Set 11 | waitati
# Processing Record 34 of Set 11 | bumba
# Processing Record 35 of Set 11 | champerico
# Processing Record 36 of Set 11 | dingle
# Processing Record 37 of Set 11 | potosi
# Processing Record 38 of Set 11 | solnechnyy
# Processing Record 39 of Set 11 | severo-yeniseyskiy
# Processing Record 40 of Set 11 | adelaide
# Processing Record 41 of Set 11 | namibe
# Processing Record 42 of Set 11 | kieta
# Processing Record 43 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 11 | lensk
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | uribia
# Processing Record 47 of Set 11 | krasnoselkup
# Processing Record 48 of Set 11 | unai
# Processing Record 49 of Set 11 | praia
# Processing Record 0 of Set 12 | itoigawa
# Processing Record 1 of Set 12 | abapo
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | wanaka
# Processing Record 4 of Set 12 | mian channun
# Processing Record 5 of Set 12 | sarangani
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | vostok
# Processing Record 8 of Set 12 | lisakovsk
# Processing Record 9 of Set 12 | kloulklubed
# Processing Record 10 of Set 12 | monywa
# Processing Record 11 of Set 12 | port shepstone
# Processing Record 12 of Set 12 | dunedin
# Processing Record 13 of Set 12 | mangan
# Processing Record 14 of Set 12 | gunjur
# Processing Record 15 of Set 12 | wajir
# Processing Record 16 of Set 12 | gwadar
# Processing Record 17 of Set 12 | alenquer
# Processing Record 18 of Set 12 | corsicana
# Processing Record 19 of Set 12 | nakhon thai
# Processing Record 20 of Set 12 | terrace
# Processing Record 21 of Set 12 | port moresby
# Processing Record 22 of Set 12 | bosobolo
# Processing Record 23 of Set 12 | susanville
# Processing Record 24 of Set 12 | aljezur
# Processing Record 25 of Set 12 | saint-joseph
# Processing Record 26 of Set 12 | angoche
# Processing Record 27 of Set 12 | warah
# Processing Record 28 of Set 12 | tutoia
# Processing Record 29 of Set 12 | debre tabor
# Processing Record 30 of Set 12 | manzanillo
# Processing Record 31 of Set 12 | manga
# Processing Record 32 of Set 12 | sendai
# Processing Record 33 of Set 12 | bosaso
# Processing Record 34 of Set 12 | senno
# Processing Record 35 of Set 12 | rockland
# Processing Record 36 of Set 12 | san jose
# Processing Record 37 of Set 12 | makokou
# Processing Record 38 of Set 12 | esfahan
# Processing Record 39 of Set 12 | sumbe
# Processing Record 40 of Set 12 | port keats
# Processing Record 41 of Set 12 | wajima
# Processing Record 42 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 43 of Set 12 | komsomolskiy
# Processing Record 44 of Set 12 | kargala
# Processing Record 45 of Set 12 | zaigrayevo
# Processing Record 46 of Set 12 | tabou
# Processing Record 47 of Set 12 | bilibino
# Processing Record 48 of Set 12 | aklavik
# Processing Record 49 of Set 12 | miandrivazo
# Processing Record 0 of Set 13 | talcahuano
# Processing Record 1 of Set 13 | loralai
# Processing Record 2 of Set 13 | tres picos
# Processing Record 3 of Set 13 | esperance
# Processing Record 4 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 13 | yarim
# Processing Record 6 of Set 13 | buena vista
# Processing Record 7 of Set 13 | salalah
# Processing Record 8 of Set 13 | olinda
# Processing Record 9 of Set 13 | keta
# Processing Record 10 of Set 13 | sakakah
# Processing Record 11 of Set 13 | akyab
# Processing Record 12 of Set 13 | tuatapere
# Processing Record 13 of Set 13 | lillesand
# Processing Record 14 of Set 13 | funehiki
# Processing Record 15 of Set 13 | caceres
# Processing Record 16 of Set 13 | houma
# Processing Record 17 of Set 13 | corrales
# Processing Record 18 of Set 13 | liverpool
# Processing Record 19 of Set 13 | okato
# Processing Record 20 of Set 13 | chapais
# Processing Record 21 of Set 13 | kawalu
# Processing Record 22 of Set 13 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 23 of Set 13 | aviles
# Processing Record 24 of Set 13 | vanavara
# Processing Record 25 of Set 13 | erenhot
# Processing Record 26 of Set 13 | arlit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data) 
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        xichang  27.8964  102.2634    288.54        77           1
# 1    yerbogachen  61.2767  108.0108    252.85       100          13
# 2        batagay  67.6333  134.6333    265.79        97         100
# 3       khatanga  71.9667  102.5000    253.15       100         100
# 4           roma  43.2128  -75.4557    285.78        75         100
# ..           ...      ...       ...       ...       ...         ...
# 578       kawalu  -7.3817  108.2082    296.10        98          99
# 579       aviles  43.5547   -5.9248    285.81        76           0
# 580     vanavara  60.3400  102.2797    257.27        96          90
# 581      erenhot  43.6475  111.9767    278.57        54          92
# 582        arlit  18.7369    7.3853    303.18         8           0
#
#      Wind Speed Country        Date
# 0          1.01      CN  1681763787
# 1          0.43      RU  1681763787
# 2          1.00      RU  1681763787
# 3          3.54      RU  1681763787
# 4          2.06      US  1681763788
# ..          ...     ...         ...
# 578        0.34      ID  1681763957
# 579        5.66      ES  1681763959
# 580        1.71      RU  1681763960
# 581        3.48      CN  1681763960
# 582        4.02      NE  1681763960
#
# [583 rows x 9 columns]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) 

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      xichang  27.8964  102.2634    288.54        77           1        1.01
# 1  yerbogachen  61.2767  108.0108    252.85       100          13        0.43
# 2      batagay  67.6333  134.6333    265.79        97         100        1.00
# 3     khatanga  71.9667  102.5000    253.15       100         100        3.54
# 4         roma  43.2128  -75.4557    285.78        75         100        2.06
#
#   Country        Date
# 0      CN  1681763787
# 1      RU  1681763787
# 2      RU  1681763787
# 3      RU  1681763787
# 4      US  1681763788

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            xichang  27.8964  102.2634    288.54        77           1
# 1        yerbogachen  61.2767  108.0108    252.85       100          13
# 2            batagay  67.6333  134.6333    265.79        97         100
# 3           khatanga  71.9667  102.5000    253.15       100         100
# 4               roma  43.2128  -75.4557    285.78        75         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.01      CN  1681763787
# 1              0.43      RU  1681763787
# 2              1.00      RU  1681763787
# 3              3.54      RU  1681763787
# 4              2.06      US  1681763788

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black" , alpha = 0.8)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("Ciry Max Latitude vs.Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temerature (C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black" , alpha = 0.8)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude vs.Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black" , alpha = 0.8)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude vs.Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black" , alpha = 0.8)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Max Latitude vs.Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
c_slope, c_int, c_r, c_p, c_std_err = stats.linregress(city_data_df["Lat"], city_data_df["Max Temp"])
print("max_temp")
print(c_slope, c_int, c_r, c_p, c_std_err)
# Out:
# max_temp
# -0.23693202328791313 292.86141731071154 -0.6177848853226111 1.2010094542103738e-62 0.012511596607178203

# %%
reg_value = c_slope*city_data_df["Max Temp"] + c_int
reg_value
# Out:
# City_ID
# 0      224.497051
# 1      232.953155
# 2      229.887255
# 3      232.882076
# 4      225.150984
#           ...
# 578    222.705845
# 579    225.143876
# 580    231.905916
# 581    226.859264
# 582    221.028366
# Name: Max Temp, Length: 583, dtype: float64

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            xichang  27.8964  102.2634    288.54        77           1
# 1        yerbogachen  61.2767  108.0108    252.85       100          13
# 2            batagay  67.6333  134.6333    265.79        97         100
# 3           khatanga  71.9667  102.5000    253.15       100         100
# 4               roma  43.2128  -75.4557    285.78        75         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.01      CN  1681763787
# 1              0.43      RU  1681763787
# 2              1.00      RU  1681763787
# 3              3.54      RU  1681763787
# 4              2.06      US  1681763788

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5           geraldton -28.7667  114.6000    286.38        88          77
# 8            souillac -20.5167   57.5167    298.36        83          20
# 9        port lincoln -34.7333  135.8667    288.92        90           2
# 10       jacareacanga  -6.2222  -57.7528    298.33        95         100
# 11            ushuaia -54.8000  -68.3000    277.96        65         100
#
#          Wind Speed Country        Date
# City_ID
# 5              3.60      AU  1681763789
# 8              3.60      MU  1681763790
# 9              5.08      AU  1681763791
# 10             1.57      BR  1681763791
# 11             3.09      AR  1681763501

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
northern_hemi_lat_frame =northern_hemi_df["Lat"].to_frame()
northern_hemi_lat_frame
# Out:
#              Lat
# City_ID
# 0        27.8964
# 1        61.2767
# 2        67.6333
# 3        71.9667
# 4        43.2128
# ...          ...
# 577      49.7834
# 579      43.5547
# 580      60.3400
# 581      43.6475
# 582      18.7369
#
# [397 rows x 1 columns]

# %%
northern_hemi_temp_frame = northern_hemi_df["Max Temp"].to_frame()
northern_hemi_temp_frame
# Out:
#          Max Temp
# City_ID
# 0          288.54
# 1          252.85
# 2          265.79
# 3          253.15
# 4          285.78
# ...           ...
# 577        282.03
# 579        285.81
# 580        257.27
# 581        278.57
# 582        303.18
#
# [397 rows x 1 columns]

# %%
northern_hemi_df["Lat"]
# Out:
# City_ID
# 0      27.8964
# 1      61.2767
# 2      67.6333
# 3      71.9667
# 4      43.2128
#         ...
# 577    49.7834
# 579    43.5547
# 580    60.3400
# 581    43.6475
# 582    18.7369
# Name: Lat, Length: 397, dtype: float64

# %%
northern_hemi_df["Max Temp"]
# Out:
# City_ID
# 0      288.54
# 1      252.85
# 2      265.79
# 3      253.15
# 4      285.78
#         ...
# 577    282.03
# 579    285.81
# 580    257.27
# 581    278.57
# 582    303.18
# Name: Max Temp, Length: 397, dtype: float64

# %%
mn_slope, mn_int, mn_r, mn_p, mn_std_err = stats.linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
ms_slope, ms_int, ms_r, ms_p, ms_std_err = stats.linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
print("max_temp_north")
print(mn_slope, mn_int, mn_r, mn_p, mn_std_err)
print("max_temp_south")
print(ms_slope, ms_int, ms_r, ms_p, ms_std_err)
# Out:
# max_temp_north
# -0.6204814290407408 309.464169742702 -0.8716030594818737 2.3145461732243927e-124 0.017558835278840203
# max_temp_south
# 0.33765077012753814 301.2643785717281 0.7579357573068394 5.6168232159185326e-36 0.021423639769488582

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=20,color="red")
#plt.text (30, 260, "test" 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# # Linear regression on Northern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])[0, 1]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
#plt.annotate(f"y= {round(mn_slope,2)}x+mn_int)", (6,1), color='red')
# Out:
# The r-value is:
# -0.6177848853226111

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (-50, 295, f"y={round(ms_slope,2)}x+{round(ms_int,2)}", fontsize=14, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Linear regression on Southern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])[0, 1]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %% [markdown]
# **Discussion about the linear relationship:
# For the northern hemisphere scatter plot it implies a negative correlation between the Latitude and the Max_temp. It shows a negative slope which means as the latitude increases the temperature decreases. (strong relation)
# For the southern hemisphere there is positive correlation which means as the latitude decreases the temperature decreases as well and vice verse.  (strong relation)

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
hn_slope, hn_int, hn_r, hn_p, hn_std_err = stats.linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
hs_slope, hs_int, hs_r, hs_p, hs_std_err = stats.linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
print("humidity_north")
print(hn_slope, hn_int, hn_r, hn_p, hn_std_err)
print("humidity_south")
print(hs_slope, hs_int, hs_r, hs_p, hs_std_err)
# Out:
# humidity_north
# 0.3305862511456239 54.68947547545897 0.28336908066297434 9.111334695031979e-09 0.05629338129335646
# humidity_south
# 0.19211021354110258 80.54776904357253 0.14726755742151107 0.04486987454731087 0.09512029949704057

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (50, 20, f"y={round(hn_slope,2)}x+{round(hn_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Northern Hemisphere
# # Linear regression on Northern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])[0, 1]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (-50, 40, f"y={round(hs_slope,2)}x+{round(hs_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Southern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])[0, 1]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %% [markdown]
# **Discussion about the linear relationship: For the northern hemisphere, there is moderate positive relation. There are also two clusters on the top right and left. for the southeren hemisphere there is a weak negative relation and there is also gap in values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
cn_slope, cn_int, cn_r, cn_p, cn_std_err = stats.linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
cs_slope, cs_int, cs_r, cs_p, cs_std_err = stats.linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
print("cloud_north")
print(cn_slope, cn_int, cn_r, cn_p, cn_std_err)
print("cloud_south")
print(cs_slope, cs_int, cs_r, cs_p, cs_std_err)
# Out:
# cloud_north
# 0.4513928983484213 34.934305205143765 0.21975630822808967 9.91859086115781e-06 0.10082459663410655
# cloud_south
# 0.34479113871300104 67.86167671253011 0.11798720766541002 0.1087381652265051 0.21392824102568167

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (50, 20, f"y={round(cn_slope,2)}x+{round(cn_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Northern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])[0, 1]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (-50, 20, f"y={round(cs_slope,2)}x+{round(cs_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Southern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])[0, 1]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %% [markdown]
# **Discussion about the linear relationship: In both plots, there is a noticeable relationship between the two variables being plotted, but the relationship is not extremely strong. In the southeren hemisphere, the scatter plot is not clustered tightly around a straight line, and there is gap in the values. There is also two data clusters showing northern hemisphere plot, it's displayed on the bottom and the top of the grapgh. For the southeren hemisphere plot, there are few data clusters on the top and a bit on the bottom.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
wn_slope, wn_int, wn_r, wn_p, wn_std_err = stats.linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
ws_slope, ws_int, ws_r, ws_p, ws_std_err = stats.linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
print("wind_speed_north")
print(wn_slope, wn_int, wn_r, wn_p, wn_std_err)
print("wind_speed_south")
print(ws_slope, ws_int, ws_r, ws_p, ws_std_err)
# Out:
# wind_speed_north
# 0.013703127852028506 3.2126156441055356 0.10226601041299527 0.041694859130713045 0.006706669272779961
# wind_speed_south
# -0.03078962377991122 2.440731170450366 -0.20109162823953983 0.005919500274931619 0.011057018498579891

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (20,10, f"y={round(wn_slope,2)}x+{round(wn_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Northern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])[0, 1]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(f"y={round(mn_slope,2)}x+{round(mn_int,2)}", (30,260), color='red')
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.text (-20,8, f"y={round(ws_slope,2)}x+{round(ws_int,2)}", fontsize=15, color='red') 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    plt.show()

# %%
# Southern Hemisphere
print ("The r-value is:")
print(c_r)
r = np.corrcoef(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])[0, 1]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed",(6,-10))
# Out:
# The r-value is:
# -0.6177848853226111

# %% [markdown]
# **Discussion about the linear relationship: for the Northern Hemisphere plot it displays no relationship and there is data cluster at the bottom of the plot whcih can indicate a pattern. For the Southern Hemisphere there is a weak negative relationship therefore there is a slight tendency for one variable to decrease as the other variable increases. The data points tend to cluster around a straight line with a negative slope, but there is a lot of variation in the data.
